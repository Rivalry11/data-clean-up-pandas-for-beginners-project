# %% [markdown]
# # Prácticas básicas con Python
#
# #### Ejercicio 00. Declaración de Variables
#
# Define las siguientes variables con valores que tú elijas:
#
# - Una variable que almacene tu nombre (texto).
# - Una variable que almacene tu edad (número entero).
# - Una variable que indique si te gusta la programación (verdadero o falso).
# - Una variable que almacene tu calificación promedio (número decimal).

# %%
# Declara aquí tus variables.
nombre  = "Camila"
edad = 26
programing = True
nota = 3.9

#Ejemplo
saludo = "Hola mundo"

# %% [markdown]
# - Crea una lista con tus cinco números favoritos e imprimelo.

# %%
# Lista de números favoritos
myNumbers = [11, 33, 22, 55, 44]
print(myNumbers)
# Out:
# [11, 33, 22, 55, 44]

# %% [markdown]
# - Crea un diccionario que guarde la información de un estudiante e imprimelo:
#
#         - Nombre
#         - Edad
#         - Calificación final

# %%
# Diccionario del estudiante
myAlumnList = {
    "nombre" : "Freen",
    "Edad" : 26,
    "Calificacion_Final" : 4.5
}
print(myAlumnList)
# Out:
# {'nombre': 'Freen', 'Edad': 26, 'Calificacion_Final': 4.5}

# %% [markdown]
# #### Ejercicio 01. Análisis de datos básico con estructuras nativas de python.
# Crea una lista con las calificaciones de 5 estudiantes: [8.5, 9.2, 7.8, 8.9, 10].
#
# - Calcula el promedio de las calificaciones.

# %%
# Código
import numpy as np 

listaNotas = [8.5, 9.2, 7.8, 8.9, 10]
promedio = np.mean(listaNotas)

print("El promedio de notas es: ", promedio )
# Out:
# El promedio de notas es:  8.879999999999999

# %% [markdown]
# - Encuentra la calificación más alta y la más baja.

# %%
# Código
import numpy as np 

listaNotas = [8.5, 9.2, 7.8, 8.9, 10]
maxNota = np.max(listaNotas)
minNota = np.min(listaNotas)
print("la nota mas baja es: ", minNota )
print("La nota mas alta es: ", maxNota )
# Out:
# la nota mas baja es:  7.8
# La nota mas alta es:  10.0

# %% [markdown]
# # Limpieza de bienes raíces con Pandas para un análisis eficiente
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos.
#
# ¡Comencemos!
#
#
#
#
# - Primero leamos y exploraremos el dataset

# %%
import pandas as pd

# Leer el archivo CSV
ds = pd.read_csv('assets/real_estate.csv', sep=';') # Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds # mostramos todo
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# - Muestra las primeras filas del archivo CSV

# %%
# Mostrar las primeras filas
import pandas as pd

# Leer el archivo CSV
ds = pd.read_csv('assets/real_estate.csv', sep=';') # Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds.head(10)
# Out:
#    Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0           1       153771986  False            ferrari 57 inmobiliaria
# 1           2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2           3       153430440  False                 look find boadilla
# 3           4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4           5       153180188  False            ferrari 57 inmobiliaria
# 5           6       153934794  False                            expimad
# 6           7       153848236  False                            expimad
# 7           8       153482331  False                            expimad
# 8           9       153885351  False                            expimad
# 9          10       153215459  False                            modesta
#
#    phone_realEstate                                       url_inmueble  rooms  \
# 0       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# ...

# %% [markdown]
# Perfecto, esto fue una pequeña practica. ¡Ahora empecemos con los verdaderos ejercicios!

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
casa_mas_cara = ds.loc[ds['price'].idxmax()]
print(f"La casa con direccion en {casa_mas_cara['realEstate_name']} es la mas cara y su precio es de {casa_mas_cara['price']} USD")
# Out:
# La casa con direccion en engel volkers torrelodones es la mas cara y su precio es de 8500000 USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Este ejercicio es similar al ejercicio anterior, solo que ahora buscamos la casa con el precio más bajo. Recuerda imprimir la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
casa_mas_barata = ds.loc[ds['price'].idxmin()]
print(f"La casa con direccion en {casa_mas_barata['realEstate_name']} es la mas barata y su precio es de {casa_mas_barata['price']} USD")
# Out:
# La casa con direccion en esalje es la mas barata y su precio es de 0 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`
#
# Este ejercicio es similar al anterior, pero buscamos las casas más grandes y pequeñas en base a su superficie.

# %%
# TODO
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

casa_grande = ds.loc[ds['surface'].idxmax()]

casa_pequena = ds.loc[ds['surface'].idxmin()]

print(f"La casa grande esta ubicada en {casa_grande['realEstate_name']} y su supercificie es de {casa_grande['surface']} metros.")
print(f"La casa pequeña esta ubicada en {casa_pequena['realEstate_name']} y su supercificie es de {casa_pequena['surface']} metros.")
# Out:
# La casa grande esta ubicada en habitarium inmobiliaria y su supercificie es de 249000.0 metros.
# La casa pequeña esta ubicada en toledo21 y su supercificie es de 15.0 metros.

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones contiene el dataset? (★☆☆)
#
# Cuenta el número de poblaciones únicas en la columna 'level5' e imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

poblaciones_unicas = ds['level5'].unique()

populations = ', '.join(poblaciones_unicas)

print(populations)
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bus
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores nulos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) para verificar si hay valores nulos seguido de las columnas que contiene el NAs.

# %%
# TODO
import pandas as pd

# Leer el archivo CSV
ds = pd.read_csv('assets/real_estate.csv', sep=';')

nulos_por_columna = ds.isnull().any()

columnas_con_nulos = nulos_por_columna[nulos_por_columna == True]

print(columnas_con_nulos)
# Out:
# realEstate_name     True
# phone_realEstate    True
# rooms               True
# bathrooms           True
# surface             True
# description         True
# level4              True
# level6              True
# level7              True
# level8              True
# zipCode             True
# customZone          True
# dtype: bool

# %% [markdown]
# #### Ejercicio 06. Elimina los valores nulos (NAs) del dataset, si aplica (★★☆)
#
# Despues de eliminar los valores nulos, compara el tamaño del DataFrame antes y después de la eliminación.

# %%
# TODO
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

original_shape = ds.shape

ds_limpio = ds.dropna()

nuevo_shape = ds_limpio.shape

print(f"Tamaño original: {original_shape}")
print(f"Tamaño después de eliminar nulos: {nuevo_shape}")
# Out:
# Tamaño original: (15335, 37)
# Tamaño después de eliminar nulos: (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál es la media de precios en la población de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido de la columna level5.

# %%
# TODO
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

filtro = ds['level5'] == 'Arroyomolinos (Madrid)'
precios_filtrados = ds[filtro]['price']

media_precio = precios_filtrados.mean()

print(f"La media de precios en Arroyomolinos (Madrid) es: {media_precio:.2f} USD")
# Out:
# La media de precios en Arroyomolinos (Madrid) es: 294541.60 USD

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import pandas as pd
import matplotlib.pyplot as plt

ds = pd.read_csv('assets/real_estate.csv', sep=';')

precios_arroyomolinos = ds[ds['level5'] == 'Arroyomolinos (Madrid)']['price'].dropna()

plt.figure(figsize=(10, 6))
plt.hist(precios_arroyomolinos, bins=15, edgecolor='black')
plt.title('Histograma de precios en Arroyomolinos (Madrid)')
plt.xlabel('Precio (USD)')
plt.ylabel('Frecuencia')
plt.grid(True)

plt.show()

# %% [markdown]
# **TODO: Markdown**. La gran mayoria de las casas en Arroyomolinos (Madrid) se encuentran en un rango de precios de 200000 a 400000
